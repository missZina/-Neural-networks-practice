# %% [markdown]
# <a href="https://colab.research.google.com/github/missZina/-Neural-networks-practice/blob/master/Scikit_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Scikit Image
# scikit-image is an open source Python package that works with numpy arrays. It implements algorithms and utilities for research.
#
# It’s a fairly simple and straightforward library.
# #some Filters
# skimage.filters.inverse
# skimage.filters.laplace
# skimage.filters.median
# skimage.filters.prewitt_h
# skimage.filters.prewitt_v
# kimage.filters.rank_order
# skimage.filters.roberts
# skimage.filters.gabor
# #some image:
# skimage.data.astronaut()/
# skimage.data.binary_blobs/
# skimage.data.brick()/
# skimage.data.camera()/
# skimage.data.cell()/
# skimage.data.checkerboard()/
# skimage.data.chelsea()/
# skimage.data.clock()/
# skimage.data.coffee()/
# skimage.data.coins()/
# skimage.data.colorwheel()/
# skimage.data.grass()/
# skimage.data.gravel()/
# skimage.data.horse()/
# skimage.data.hubble_deep_field()
# #The package is imported as skimage and most of the functions are found in the submodules.
# Some examples of skimage:
# # how import skimage

# %%
from skimage import data
camera = data.camera()

# %% [markdown]
# #Examples

# %%
from skimage import io
image=data.camera()
print(image)# print our image
plt.imshow(image)# show our image
# Out:
# [[156 157 160 ... 152 152 152]
#  [156 157 159 ... 152 152 152]
#  [158 157 156 ... 152 152 152]
#  ...
#  [121 123 126 ... 121 113 111]
#  [121 123 126 ... 121 113 111]
#  [121 123 126 ... 121 113 111]]

# %%
# if we run code on google colab we will upload image here
import ee
from google.colab import files
from IPython.display import Image
Uploaded = files.upload()
# Out:
#      <input type="file" id="files-a606f28c-e5a0-4aae-82a1-bf7e2108e711" name="files[]" multiple disabled />
#      <output id="result-a606f28c-e5a0-4aae-82a1-bf7e2108e711">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving robot.jpg to robot.jpg

# %%
# Uploaded image from pc
from skimage import io
my_img=io.imread("robot.jpg")
print(my_img)
plt.imshow(my_img)
# Out:
# [[[228  82   9]
#   [230  82  10]
#   [231  83  11]
#   ...
#   [255 175 114]
#   [255 177 118]
#   [255 178 119]]
#
#  [[228  82   9]
#   [230  82  10]
#   [230  82  10]
#   ...
#   [254 176 114]
#   [255 177 118]
#   [255 178 119]]
#
#  [[229  83  10]
#   [230  82  10]
#   [229  81   9]
#   ...
#   [254 176 114]
#   [255 177 118]
#   [255 178 119]]
#
#  ...
#
#  [[205 200 206]
#   [205 200 206]
#   [206 201 207]
#   ...
#   [238 239 243]
#   [238 239 243]
#   [238 239 243]]
#
#  [[206 201 207]
#   [206 201 207]
#   [206 201 207]
#   ...
#   [238 239 243]
#   [238 239 243]
#   [238 239 243]]
#
#  [[207 202 208]
#   [207 202 208]
#   [207 202 208]
#   ...
#   [238 239 243]
#   [238 239 243]
#   [238 239 243]]]

# %% [markdown]
# # Example 1

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
from skimage import data,filters
image = data.horse()
plt.imshow(image)

# %%
# use the Filter
edges = filters.meijering(image)
plt.imshow(edges)

# %% [markdown]
# #Example 2
# create a mask on an image.

# %%
import numpy as np
from skimage import data
import matplotlib.pyplot as plt 
# %matplotlib inline
image = data.camera()
plt.imshow(image)

# %% [markdown]
# # Apply a Mask

# %%
type(image) #Image est un array numpy
msk = image < 87
image[msk]=255
plt.imshow(image, cmap='gray')

# %% [markdown]
# # Example 3

# %%
from skimage.filters import gabor
from skimage import data, io
from matplotlib import pyplot as plt  
image = data.clock()
plt.imshow(image)

# %%
# detecting edges in a clock image
filt_real, filt_imag = gabor(image, frequency=0.6)
plt.figure()            
io.imshow(filt_real)    
io.show()               
# less sensitivity to finer details with the lower frequency kernel 0.1
filt_real, filt_imag = gabor(image, frequency=0.1)
plt.figure()            
io.imshow(filt_real)    
io.show() 
 # less sensitivity to finer details with the superior frequency kernel 1
filt_real, filt_imag = gabor(image, frequency=1)
plt.figure()            
io.imshow(filt_real)    
io.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %% [markdown]
# # Example 4

# %%
# Edges filtering
import ee
from skimage import io
from matplotlib import pyplot as plt
image=data.horse()     
from skimage.filters import roberts, sobel ,scharr , prewitt

edg_roberts = roberts(image)
plt.figure() 
io.imshow(edg_roberts)    
io.show()
edg_sobel = sobel(image)
plt.figure() 
io.imshow(edg_sobel)    
io.show()
edg_scharr = scharr(image)
plt.figure() 
io.imshow(edg_scharr)    
io.show()
edg_prewitt = prewitt(image)
plt.figure() 
io.imshow(edg_prewitt)    
io.show()
from skimage.feature import canny
edg_canny = canny(image)
plt.imshow(edg_canny)
